# %%
#Problem 48

# %%
x = var('x')

# %%
y = function('y')(x)

# %%
soln = desolve(diff(y,x) - 5/y, y)

# %%
soln
# Out:
# 1/10*y(x)^2 == _C + x

# %%
C = var('C')

# %%
solve([y^2 - 10*x - C == 0], y)
# Out:
# [y(x) == -sqrt(C + 10*x), y(x) == sqrt(C + 10*x)]

# %%
def f1(x,y): return y^2 - 10*x - 5

# %%
def f2(x,y): return y^2 - 10*x + 200

# %%
def f3(x,y): return y^2 - 10*x - 100

# %%
p = []

# %%
p.append(implicit_plot(f1,(x,-0.5,15),(y,-15,15), color='blue', legend_label='C1 = 5', title='Particular Solutions to dy/dx = 5/y'))

# %%
p.append(implicit_plot(f2,(x,20,35),(y,-15,15), color='red', legend_label='C1 = -200'))

# %%
p.append(implicit_plot(f3,(x,-10,5),(y,-15,15), color='green', legend_label='C1 = 100'))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives
